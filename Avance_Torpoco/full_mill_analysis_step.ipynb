# %% [markdown]
# # Análisis Completo de Molinos - Paso a Paso
#
# Este notebook contiene el análisis completo de datos de molinos de bolas para predicción de fallas.
#
# ## ⚠️ IMPORTANTE: Configurar rutas de archivos
#
# Antes de ejecutar, **CAMBIAR** las siguientes rutas en las celdas correspondientes:
#
# ```python
# # CAMBIAR estas rutas por las de tu sistema:
# DATA_PATH = "tu_ruta/molinos_shift_summary_full.csv"  # o el archivo que uses
# OUTPUT_DIR = "tu_ruta/resultados/"                    # donde guardar resultados
# ```

# %%
# ════════════════════════════════════════════════════════════
# CONFIGURACIÓN INICIAL - CAMBIAR RUTAS AQUÍ
# ════════════════════════════════════════════════════════════

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# ⚠️ CAMBIAR ESTAS RUTAS POR LAS DE TU SISTEMA:
DATA_PATH = "molinos_shift_summary_full.csv"    # ← CAMBIAR: ruta a tu archivo de datos
OUTPUT_DIR = "resultados/"                      # ← CAMBIAR: carpeta donde guardar resultados

# Crear directorio de salida si no existe
Path(OUTPUT_DIR).mkdir(parents=True, exist_ok=True)

print("✅ Configuración inicial completada")
print(f"📂 Archivo de datos: {DATA_PATH}")
print(f"📁 Directorio de salida: {OUTPUT_DIR}")
